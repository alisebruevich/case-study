# %%
import numpy as np
import pandas as pd

# %%
countries = pd.read_csv("HNP_StatsCountry-Series.csv")
country_stats = pd.read_csv("HNP_StatsCountry.csv")
stats_data = pd.read_csv("HNP_StatsData.csv")
stats_footnotes = pd.read_csv("HNP_StatsFootNote.csv")
stats_seriestime = pd.read_csv("HNP_StatsSeries-Time.csv")
stats_series = pd.read_csv("HNP_StatsSeries.csv")

# %%
countries
# Out:
#      CountryCode         SeriesCode  \
# 0            ABW     SP.DYN.AMRT.MA
# 1            ABW  SP.DYN.LE00.MA.IN
# 2            ABW     SP.DYN.CDRT.IN
# 3            ABW     SP.DYN.AMRT.FE
# 4            ABW        SM.POP.NETM
# ...          ...                ...
# 3363         ZWE  SP.DYN.LE00.MA.IN
# 3364         ZWE     SP.DYN.CBRT.IN
# 3365         ZWE     SP.DYN.AMRT.FE
# 3366         ZWE        SP.POP.TOTL
# 3367         ZWE     SP.DYN.AMRT.MA
#
#                                             DESCRIPTION  Unnamed: 3
# 0     Data source: United Nations World Population P...         NaN
# 1     Data source: United Nations World Population P...         NaN
# 2     Data source: United Nations World Population P...         NaN
# 3     Data source: United Nations World Population P...         NaN
# 4     Data source: United Nations World Population P...         NaN
# ...                                                 ...         ...
# ...

# %%
country_stats
# Out:
#     Country Code    Short Name    Table Name                     Long Name  \
# 0            ABW         Aruba         Aruba                         Aruba
# 1            AFG   Afghanistan   Afghanistan  Islamic State of Afghanistan
# 2            AGO        Angola        Angola   People's Republic of Angola
# 3            ALB       Albania       Albania           Republic of Albania
# 4            AND       Andorra       Andorra       Principality of Andorra
# ..           ...           ...           ...                           ...
# 253          XKX        Kosovo        Kosovo            Republic of Kosovo
# 254          YEM         Yemen   Yemen, Rep.             Republic of Yemen
# 255          ZAF  South Africa  South Africa      Republic of South Africa
# 256          ZMB        Zambia        Zambia            Republic of Zambia
# 257          ZWE      Zimbabwe      Zimbabwe          Republic of Zimbabwe
#
#     2-alpha code       Currency Unit  \
# ...

# %%
stats_data
# Out:
#        Country Name Country Code  \
# 0        Arab World          ARB
# 1        Arab World          ARB
# 2        Arab World          ARB
# 3        Arab World          ARB
# 4        Arab World          ARB
# ...             ...          ...
# 109293     Zimbabwe          ZWE
# 109294     Zimbabwe          ZWE
# 109295     Zimbabwe          ZWE
# 109296     Zimbabwe          ZWE
# 109297     Zimbabwe          ZWE
#
#                                            Indicator Name     Indicator Code  \
# 0       Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 1       Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 2       Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
# 3                       Adults (ages 15+) living with HIV        SH.DYN.AIDS
# 4             Adults (ages 15-49) newly infected with HIV        SH.HIV.INCD
# ...                                                   ...                ...
# ...

# %%
stats_footnotes
# Out:
#        CountryCode         SeriesCode    Year  \
# 0              ABW     SE.ADT.LITR.ZS  YR2018
# 1              ABW  SE.ADT.LITR.MA.ZS  YR2018
# 2              ABW     SP.DYN.SMAM.FE  YR2010
# 3              ABW     SP.DYN.SMAM.FE  YR2000
# 4              ABW     SP.DYN.SMAM.FE  YR1991
# ...            ...                ...     ...
# 443055         ZWE  SH.HIV.INCD.50.P3  YR2002
# 443056         ZWE  SH.HIV.INCD.50.P3  YR2001
# 443057         ZWE  SH.HIV.INCD.50.P3  YR2000
# 443058         ZWE  SH.HIV.INCD.50.P3  YR1999
# 443059         ZWE  SH.HIV.INCD.50.P3  YR1998
#
#                             DESCRIPTION  Unnamed: 4
# 0                        UIS Estimation         NaN
# 1                        UIS Estimation         NaN
# 2            Source: Aruba 2010 Census.         NaN
# 3            Source: Aruba 2000 Census.         NaN
# 4            Source: Aruba 1991 Census.         NaN
# ...                                 ...         ...
# ...

# %%
stats_seriestime
# Out:
#             SeriesCode    Year  \
# 0          SP.ADO.TFRT  YR1960
# 1    SP.DYN.TO65.FE.ZS  YR1960
# 2    SP.DYN.TO65.MA.ZS  YR1960
# 3       SP.DYN.AMRT.FE  YR1960
# 4       SP.DYN.AMRT.MA  YR1960
# ..                 ...     ...
# 415        SP.ADO.TFRT  YR2018
# 416     SP.POP.BRTH.MF  YR2018
# 417     SH.MLR.IPTP.ZS  YR2018
# 418     SH.MLR.NETS.ZS  YR2018
# 419  SP.DYN.TO65.FE.ZS  YR2018
#
#                                            DESCRIPTION  Unnamed: 3
# 0           Interpolated using data for 1957 and 1962.         NaN
# 1           Interpolated using data for 1957 and 1962.         NaN
# 2           Interpolated using data for 1957 and 1962.         NaN
# 3    Interpolated using data for 1957 and 1962, if ...         NaN
# 4    Interpolated using data for 1957 and 1962, if ...         NaN
# ..                                                 ...         ...
# 415          Interpolated using data for 2017 and 2022         NaN
# ...

# %%
stats_series
# Out:
#            Series Code                                 Topic  \
# 0          HD.HCI.OVRL  Public Sector: Policy & institutions
# 1       HD.HCI.OVRL.FE  Public Sector: Policy & institutions
# 2       HD.HCI.OVRL.LB  Public Sector: Policy & institutions
# 3    HD.HCI.OVRL.LB.FE  Public Sector: Policy & institutions
# 4    HD.HCI.OVRL.LB.MA  Public Sector: Policy & institutions
# ..                 ...                                   ...
# 417     SP.RUR.TOTL.ZS   Environment: Density & urbanization
# 418        SP.URB.GROW   Environment: Density & urbanization
# 419        SP.URB.TOTL   Environment: Density & urbanization
# 420  SP.URB.TOTL.IN.ZS   Environment: Density & urbanization
# 421        SP.UWT.TFRT           Health: Reproductive health
#
#                                         Indicator Name Short definition  \
# 0                Human capital index (HCI) (scale 0-1)              NaN
# 1        Human capital index (HCI), female (scale 0-1)              NaN
# ...
